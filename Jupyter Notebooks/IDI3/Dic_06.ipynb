# %%
# Mawrer Amed Ramirez Martinez
# Avance de TOG IDI 3
# ms723737@iteso.mx

import numpy as np
np.random.seed(1)
from tensorflow import set_random_seed 
set_random_seed(2)

from keras import backend as K

from statsmodels.tsa.arima_model import ARIMA

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score


import seaborn as sns
from scipy import stats

import matplotlib.pyplot as plt
from matplotlib import pyplot
from matplotlib.pyplot import figure

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
import tensorflow as tf 
from keras import metrics
from keras.callbacks import ModelCheckpoint

import pandas as pd 
import math as m
import os, glob
# Out:
# Using TensorFlow backend.

# %%
RANGE = 51

HYPER_L1_IN = RANGE
EPOCHS = 100
BATCH_SIZE = 32

TEST_SIZE = .19
VAL_SIZE = .0

START_IN = 0

TRAINING_TIME_ELAPSED = 0

TRAIN_MSE=0
TRAIN_RMSE=0
TRAIN_MAE=0
TEST_MSE=0
TEST_RMSE=0
TEST_MAE=0

# %%
#LOAD DATASET for ASK
# change column names
#load Dataset for BID
#change column names

cwd = os.getcwd()
source_data = os.path.join(cwd, r'proj_deep/')
filenames = glob.glob(source_data + "/*.csv")
filenames.sort()
for file in filenames:
    print(os.path.basename(file))

dateparse = lambda x: pd.datetime.strptime(x, '%d.%m.%Y %H:%M:%S.%f')
DF_EURUSD_ASK = pd.read_csv(filenames[1], parse_dates=['Gmt time'], date_parser=dateparse, index_col=None, header=0)
print(DF_EURUSD_ASK.columns)
DF_EURUSD_ASK.rename(columns={'Gmt time':'timestamp',
                             'Open':'open_ask',
                             'High':'high_ask',
                             'Low':'low_ask',
                             'Close':'close_ask',
                             'Volume':'volume_ask'},
                    inplace=True)
print(DF_EURUSD_ASK.columns)

print(DF_EURUSD_ASK.head())
print(DF_EURUSD_ASK.tail())
# Out:
# EURUSD_ASK_01.01.2004-19.11.2019.csv
# EURUSD_Candlestick_1_Hour_ASK_31.07.2018-31.07.2019.csv
# EURUSD_Candlestick_1_Hour_BID_31.07.2018-31.07.2019.csv
# Index(['Gmt time', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')
# Index(['timestamp', 'open_ask', 'high_ask', 'low_ask', 'close_ask',
#        'volume_ask'],
#       dtype='object')
#             timestamp  open_ask  high_ask  low_ask  close_ask  volume_ask
# 0 2018-08-01 00:00:00   1.16894   1.16926  1.16885    1.16905   6394.8501
# 1 2018-08-01 01:00:00   1.16905   1.16914  1.16832    1.16895   7304.5498
# 2 2018-08-01 02:00:00   1.16896   1.16920  1.16823    1.16854   6709.3501
# 3 2018-08-01 03:00:00   1.16854   1.16880  1.16799    1.16799   6154.0601
# 4 2018-08-01 04:00:00   1.16799   1.16833  1.16761    1.16779   5269.6699
#                timestamp  open_ask  high_ask  low_ask  close_ask  volume_ask
# 6246 2019-08-01 19:00:00   1.10854   1.10945  1.10798    1.10930  30454.0801
# 6247 2019-08-01 20:00:00   1.10928   1.10938  1.10837    1.10855  10253.6504
# 6248 2019-08-01 21:00:00   1.10855   1.10862  1.10805    1.10833   4365.2798
# 6249 2019-08-01 22:00:00   1.10835   1.10850  1.10748    1.10788   4208.5298
# 6250 2019-08-01 23:00:00   1.10787   1.10833  1.10780    1.10793   6057.7402

# %%
print(DF_EURUSD_ASK.shape)
#DF_EURUSD_ASK2 = DF_EURUSD_ASK.iloc[3500:]
DF_EURUSD_ASK2 = DF_EURUSD_ASK
print(DF_EURUSD_ASK2.shape)
# Out:
# (6251, 6)
# (6251, 6)

# %%
#Describe Dataframe ASK

print('Shape: ', DF_EURUSD_ASK2.shape)
print(DF_EURUSD_ASK2.describe())
print(DF_EURUSD_ASK2.head())
#date_series = pd.to_datetime(DF_EURUSD_ASK['timestamp'][0])
DF_EURUSD_ASK2 = DF_EURUSD_ASK2.drop(['timestamp'], axis = 1)
print(DF_EURUSD_ASK2.dtypes)
# Out:
# Shape:  (6251, 6)
#           open_ask     high_ask      low_ask    close_ask     volume_ask
# count  6251.000000  6251.000000  6251.000000  6251.000000    6251.000000
# mean      1.136863     1.137463     1.136255     1.136855   12982.056088
# std       0.014978     0.015061     0.014905     0.014978    8909.610064
# min       1.102980     1.104150     1.102710     1.102990       5.250000
# 25%       1.125685     1.126140     1.125130     1.125685    6613.855000
# 50%       1.135000     1.135680     1.134430     1.134990   11323.240200
# 75%       1.144675     1.145370     1.143900     1.144655   17256.754850
# max       1.179880     1.181540     1.177980     1.179870  252673.546900
#             timestamp  open_ask  high_ask  low_ask  close_ask  volume_ask
# 0 2018-08-01 00:00:00   1.16894   1.16926  1.16885    1.16905   6394.8501
# 1 2018-08-01 01:00:00   1.16905   1.16914  1.16832    1.16895   7304.5498
# 2 2018-08-01 02:00:00   1.16896   1.16920  1.16823    1.16854   6709.3501
# 3 2018-08-01 03:00:00   1.16854   1.16880  1.16799    1.16799   6154.0601
# 4 2018-08-01 04:00:00   1.16799   1.16833  1.16761    1.16779   5269.6699
# open_ask      float64
# high_ask      float64
# low_ask       float64
# close_ask     float64
# volume_ask    float64
# dtype: object

# %%
#Moving Average  
def MA(df, n): 
    MA = pd.Series(df['close_ask'].rolling(n).mean(), name = 'MA_' + str(n)) 
    df = df.join(MA)  
    return df

# %%
DF_EURUSD_ASK_MA25 = MA(DF_EURUSD_ASK2, 25)
print(DF_EURUSD_ASK_MA25)
# Out:
#       open_ask  high_ask  low_ask  close_ask  volume_ask     MA_25
# 0      1.16894   1.16926  1.16885    1.16905   6394.8501       NaN
# 1      1.16905   1.16914  1.16832    1.16895   7304.5498       NaN
# 2      1.16896   1.16920  1.16823    1.16854   6709.3501       NaN
# 3      1.16854   1.16880  1.16799    1.16799   6154.0601       NaN
# 4      1.16799   1.16833  1.16761    1.16779   5269.6699       NaN
# 5      1.16779   1.16821  1.16761    1.16804   8515.1699       NaN
# 6      1.16805   1.16857  1.16723    1.16821  14354.9902       NaN
# 7      1.16821   1.16942  1.16770    1.16877  14436.9502       NaN
# 8      1.16877   1.16905  1.16815    1.16820  11943.6904       NaN
# 9      1.16820   1.16855  1.16775    1.16831  10390.4805       NaN
# 10     1.16831   1.16875  1.16807    1.16867  10072.8203       NaN
# 11     1.16866   1.16880  1.16811    1.16864  11361.8203       NaN
# 12     1.16862   1.16998  1.16833    1.16903  16363.9697       NaN
# 13     1.16904   1.16922  1.16763    1.16779  15235.9502       NaN
# 14     1.16777   1.16867  1.16688    1.16727  16680.6699       NaN
# 6250   1.10787   1.10833  1.10780    1.10793   6057.7402  1.105772
#
# [6251 rows x 6 columns]

# %%
DF_EURUSD_ASK_MA50 = MA(DF_EURUSD_ASK_MA25, 50)
print(DF_EURUSD_ASK_MA50)
# Out:
#       open_ask  high_ask  low_ask  close_ask  volume_ask     MA_25     MA_50
# 0      1.16894   1.16926  1.16885    1.16905   6394.8501       NaN       NaN
# 1      1.16905   1.16914  1.16832    1.16895   7304.5498       NaN       NaN
# 2      1.16896   1.16920  1.16823    1.16854   6709.3501       NaN       NaN
# 3      1.16854   1.16880  1.16799    1.16799   6154.0601       NaN       NaN
# 4      1.16799   1.16833  1.16761    1.16779   5269.6699       NaN       NaN
# 5      1.16779   1.16821  1.16761    1.16804   8515.1699       NaN       NaN
# 6      1.16805   1.16857  1.16723    1.16821  14354.9902       NaN       NaN
# 7      1.16821   1.16942  1.16770    1.16877  14436.9502       NaN       NaN
# 8      1.16877   1.16905  1.16815    1.16820  11943.6904       NaN       NaN
# 9      1.16820   1.16855  1.16775    1.16831  10390.4805       NaN       NaN
# 10     1.16831   1.16875  1.16807    1.16867  10072.8203       NaN       NaN
# 11     1.16866   1.16880  1.16811    1.16864  11361.8203       NaN       NaN
# 12     1.16862   1.16998  1.16833    1.16903  16363.9697       NaN       NaN
# 13     1.16904   1.16922  1.16763    1.16779  15235.9502       NaN       NaN
# 14     1.16777   1.16867  1.16688    1.16727  16680.6699       NaN       NaN
# 15     1.16728   1.16764  1.16643    1.16651  13410.1104       NaN       NaN
# 16     1.16650   1.16693  1.16606    1.16680  12218.3203       NaN       NaN
# 17     1.16679   1.16700  1.16575    1.16681  33530.9414       NaN       NaN
# 18     1.16682   1.16778  1.16619    1.16643  14452.8496       NaN       NaN
# 19     1.16640   1.16659  1.16587    1.16625   9141.9297       NaN       NaN
# 20     1.16626   1.16636  1.16590    1.16600   5964.3999       NaN       NaN
# 21     1.16603   1.16629  1.16588    1.16606   3906.8401       NaN       NaN
# 22     1.16607   1.16647  1.16602    1.16634   2223.7000       NaN       NaN
# 23     1.16633   1.16658  1.16626    1.16635   2641.7900       NaN       NaN
# 24     1.16635   1.16656  1.16607    1.16620   5376.7500  1.167560       NaN
# 25     1.16621   1.16678  1.16616    1.16653   7476.5400  1.167459       NaN
# 26     1.16652   1.16657  1.16541    1.16548   6827.3799  1.167320       NaN
# 27     1.16549   1.16566  1.16507    1.16510   6912.6001  1.167183       NaN
# 28     1.16510   1.16529  1.16456    1.16476   5247.7002  1.167054       NaN
# 29     1.16474   1.16521  1.16464    1.16507   7026.7402  1.166945       NaN
# ...        ...       ...      ...        ...         ...       ...       ...
# 6221   1.11389   1.11398  1.10647    1.10852  57456.0195  1.114697  1.114588
# 6222   1.10852   1.11037  1.10664    1.10698  37761.4688  1.114349  1.114443
# 6223   1.10698   1.10776  1.10604    1.10761   8700.9600  1.114020  1.114301
# 6224   1.10760   1.10839  1.10700    1.10718   3318.6599  1.113684  1.114149
# 6225   1.10726   1.10797  1.10726    1.10795   3728.4500  1.113378  1.114018
# 6239   1.10344   1.10415  1.10272    1.10299  27376.4199  1.107320  1.111285
# 6240   1.10298   1.10469  1.10273    1.10437  29996.4492  1.106890  1.111070
# 6241   1.10437   1.10624  1.10437    1.10580  38197.0508  1.106554  1.110877
# 6242   1.10581   1.10700  1.10564    1.10609  27236.1797  1.106261  1.110699
# 6243   1.10608   1.10700  1.10586    1.10686  16422.8594  1.106016  1.110560
# 6244   1.10684   1.10960  1.10643    1.10832  42357.6992  1.105836  1.110430
# 6245   1.10831   1.10889  1.10759    1.10854  42222.0703  1.105622  1.110296
# 6246   1.10854   1.10945  1.10798    1.10930  30454.0801  1.105654  1.110175
# 6247   1.10928   1.10938  1.10837    1.10855  10253.6504  1.105716  1.110033
# 6248   1.10855   1.10862  1.10805    1.10833   4365.2798  1.105745  1.109883
# 6249   1.10835   1.10850  1.10748    1.10788   4208.5298  1.105773  1.109729
# 6250   1.10787   1.10833  1.10780    1.10793   6057.7402  1.105772  1.109575
#
# [6201 rows x 7 columns]
# (6201, 7)

# %%
DF_Full = DF_loc
DF_Full.reset_index(drop=True, inplace=True) #reset indexes from iloc
print(DF_Full.shape)
print(DF_Full.columns)
print(DF_Full.head(10))
# Out:
# (6201, 7)
# Index(['open_ask', 'high_ask', 'low_ask', 'close_ask', 'volume_ask', 'MA_25',
#        'MA_50'],
#       dtype='object')
#    open_ask  high_ask  low_ask  close_ask  volume_ask     MA_25     MA_50
# 0   1.15837   1.15883  1.15814    1.15880   6212.9302  1.161234  1.164347
# 1   1.15880   1.15933  1.15877    1.15910   5643.0000  1.160979  1.164150
# 2   1.15909   1.15933  1.15893    1.15920   3644.9399  1.160743  1.163963
# 3   1.15920   1.15952  1.15903    1.15910   4889.7598  1.160517  1.163785
# 4   1.15909   1.15909  1.15772    1.15784  11832.5801  1.160228  1.163586
# 5   1.15784   1.15910  1.15622    1.15623  15047.8799  1.159954  1.163350
# 6   1.15621   1.15795  1.15618    1.15794  13265.4902  1.159746  1.163145
# 7   1.15794   1.15850  1.15747    1.15753  11351.4805  1.159566  1.162920
# 8   1.15753   1.15800  1.15727    1.15798   8600.7002  1.159427  1.162715
# 9   1.15798   1.16107  1.15797    1.15964  17741.5996  1.159322  1.162542

# %%
total = DF_Full.shape[0]
print('Total: ', total)
print('Start: ', START_IN)
# Out:
# Total:  6201
# Start:  0

# %%
#Shape the first START of the total
DF_Full = DF_Full.iloc[START_IN:]
DF_Full.reset_index(drop=True, inplace=True) #reset indexes from iloc
print(DF_Full.shape)
# Out:
# (6201, 7)

# %%
total = DF_Full.shape[0]
print('Total: ', total)
# Out:
# Total:  6201

# %%
#generate the VECTOR Y
close_y = DF_Full['close_ask'].iloc[1:]
close_y.columns = ['close_y']
print(close_y.tail())
print(close_y.shape)
close_y = close_y.append(close_y.tail(1), ignore_index=True)
print(close_y.tail())
print(close_y.shape)
# Out:
# 6196    1.10930
# 6197    1.10855
# 6198    1.10833
# 6199    1.10788
# 6200    1.10793
# Name: close_ask, dtype: float64
# (6200,)
# 6196    1.10855
# 6197    1.10833
# 6198    1.10788
# 6199    1.10793
# 6200    1.10793
# Name: close_ask, dtype: float64
# (6201,)

# %%
s1 = TEST_SIZE + VAL_SIZE
print('Sum of %s:',s1)
f1 = int(total * s1)
print('count of Val and Test:',f1)
end_train = total - f1
print('end of train: ', end_train)

count_val= int(total * VAL_SIZE)
print('count val: ',count_val)

count_test= int(total * TEST_SIZE)
print('count test: ',count_test)


end_val = end_train + count_val
print('end_val', end_val)
# Out:
# Sum of %s: 0.19
# count of Val and Test: 1178
# end of train:  5023
# count val:  0
# count test:  1178
# end_val 5023

# %%
data_training = DF_Full.iloc[:end_train]
data_val = DF_Full.iloc[end_train: end_val]
data_test = DF_Full.iloc[end_val:]

print(data_training.shape)
print(data_val.shape)
print(data_test.shape)

data_training_y = close_y.iloc[:end_train]
data_val_y = close_y.iloc[end_train: end_val]
data_test_y = close_y.iloc[end_val:]

print(data_training_y.shape)
print(data_val_y.shape)
print(data_test_y.shape)
# Out:
# (5023, 7)
# (0, 7)
# (1178, 7)
# (5023,)
# (0,)
# (1178,)

# %%
# DATA SET SCALER TRAINING
scaler = MinMaxScaler(feature_range=(0, 1))
#print(data_training.head)
data_training_array = np.array(data_training)
data_training_array_scaled = scaler.fit_transform(data_training_array)
print(data_training_array_scaled)
# Out:
# [[0.68133333 0.66812801 0.70502528 ... 0.0245685  0.74818055 0.80645568]
#  [0.6877037  0.67543475 0.71439191 ... 0.02231285 0.74417085 0.80327339]
#  [0.692      0.67543475 0.71677074 ... 0.01440501 0.74046281 0.80025588]
#  ...
#  [0.12681481 0.11500804 0.14927148 ... 0.02079022 0.08502709 0.04348585]
#  [0.12622222 0.11471577 0.14570324 ... 0.01705699 0.08680569 0.04499137]
#  [0.12814815 0.11968435 0.15254237 ... 0.00423239 0.08862199 0.04684259]]

# %%
plt.figure(figsize=(14,5))
pyplot.plot(data_training_array_scaled[4500:,3], color = 'red', label = 'Close')
pyplot.plot(data_training_array_scaled[4500:,5], color = 'blue', label = 'MA_25')
pyplot.plot(data_training_array_scaled[4500:,6], color = 'green', label = 'MA_50')
plt.title('Close, promedio móvil de 25 y 50')
plt.xlabel('Tiempo')
plt.ylabel('Precio')
plt.legend()
plt.show()

# %%
pyplot.figure(figsize=(16,5))
pyplot.plot(data_training_y)

# %%
X_train = []
y_train = []
for i in range(RANGE, data_training_array_scaled.shape[0]):
    X_train.append(data_training_array_scaled[i-RANGE:i])
    y_train.append(data_training_y[i])

X_train_np, y_train_np = np.array(X_train), np.array(y_train)

print(X_train_np.shape)
print(y_train_np.shape)
# Out:
# (4972, 51, 7)
# (4972,)

# %%
sns.distplot(y_train_np);

# %%
#Obtener los ultimos valores de Train para agregarlos a Val DF
# APPEND DE X
last_range_training_x = data_training.tail(RANGE)
print(last_range_training_x.shape)
print(data_val.shape)
data_val_x1 = last_range_training_x.append(data_val, ignore_index = True)
data_val_x1.shape
print(data_val_x1.head)
# Out:
# (51, 7)
# (0, 7)
# <bound method NDFrame.head of     open_ask  high_ask  low_ask  close_ask  volume_ask     MA_25     MA_50
# 0    1.11597   1.11599  1.11532    1.11537   9492.2695  1.116054  1.116025
# 1    1.11536   1.11549  1.11501    1.11508   3658.7000  1.116011  1.115991
# 41   1.11828   1.12008  1.11828    1.11957  26237.7500  1.117824  1.116502
# 42   1.11956   1.11991  1.11877    1.11966  27496.2402  1.118067  1.116562
# 43   1.11966   1.12106  1.11927    1.12048  25988.2695  1.118354  1.116638
# 44   1.12049   1.12098  1.11965    1.11972  20788.7695  1.118547  1.116706
# 45   1.11973   1.12061  1.11967    1.12054  10312.0195  1.118684  1.116809
# 46   1.12054   1.12123  1.12053    1.12104  10506.1602  1.118796  1.116916
# 47   1.12106   1.12106  1.12061    1.12093   6450.7798  1.118922  1.117020
# 48   1.12094   1.12098  1.12076    1.12090   5258.2798  1.119028  1.117115
# 49   1.12090   1.12096  1.12052    1.12065   4315.0098  1.119141  1.117208
# 50   1.12103   1.12130  1.12098    1.12110   1074.6400  1.119256  1.117323>

# %%
#Append de los datos de Train al DF de Val en Y
last_range_train_y = data_training_y.tail(RANGE)
print(last_range_train_y.shape)
print(data_val_y.shape)
data_val_y1 = last_range_train_y.append(data_val_y, ignore_index = True)
data_val_y1.shape
print(data_val_y1.head(10))
# Out:
# (51,)
# (0,)
# 0    1.11508
# 1    1.11526
# 2    1.11569
# 3    1.11556
# 4    1.11529
# 5    1.11521
# 6    1.11520
# 7    1.11506
# 8    1.11494
# 9    1.11499
# Name: close_ask, dtype: float64

# %%
data_val_x2 = scaler.transform(data_val_x1)
data_val_x2.shape
print(data_val_x2[:10])
# Out:
# [[0.05318519 0.0420868  0.06839132 0.04416123 0.03754733 0.03830587
#   0.02587182]
#  [0.04414815 0.03478007 0.06378234 0.03986366 0.01445947 0.03763339
#   0.02532905]
#  [0.04       0.03390326 0.0646744  0.04253112 0.00747664 0.03708033
#   0.02491875]
#  [0.04325926 0.03857957 0.06794529 0.04890338 0.01371799 0.03670953
#   0.02459567]
#  [0.04918519 0.0382873  0.07091882 0.04697688 0.01562277 0.03619418
#   0.02418537]
#  [0.04696296 0.03580301 0.06630984 0.0429757  0.02375957 0.03545885
#   0.02368137]
#  [0.04325926 0.03361099 0.06125483 0.04179016 0.03413772 0.03489322
#   0.02318707]
#  [0.04192593 0.03229578 0.0608088  0.04164197 0.0380506  0.03408877
#   0.02276061]
#  [0.04177778 0.03200351 0.06199822 0.03956728 0.03314171 0.03346029
#   0.02223723]
#  [0.03955556 0.02849627 0.06125483 0.03778897 0.02528992 0.03266212
#   0.02174292]]

# %%
X_val = []
y_val = []
for i in range(RANGE, data_val_x2.shape[0]):
    X_val.append(data_val_x2[i-RANGE:i])
    y_val.append(data_val_y1[i])

X_val_np = np.array(X_val)
y_val_np = np.array(y_val)
print(X_val_np.shape)
print(y_val_np.shape)
# Out:
# (0,)
# (0,)

# %%
#Obtener los ultimos valores de Val para agregarlos a TEST DF
# Append en X
last_range_data_training_x = data_training.tail(RANGE)
print(last_range_data_training_x.shape)
print(data_test.shape)
data_test_x1 = last_range_data_training_x.append(data_test, ignore_index = True)
data_test_x1.shape
# Out:
# (51, 7)
# (1178, 7)
# (1229, 7)

# %%
#Append de los datos de Val al DF de Test de Y
last_range_training_y = data_training_y.tail(RANGE)
print(last_range_training_y.shape)
print(data_test_y.shape)
data_test_y1 = last_range_training_y.append(data_test_y, ignore_index = True)
data_test_y1.shape
# Out:
# (51,)
# (1178,)
# (1229,)

# %%
data_test_x2 = scaler.transform(data_test_x1)
data_test_x2.shape
print(data_test_x2[:10])
# Out:
# [[0.05318519 0.0420868  0.06839132 0.04416123 0.03754733 0.03830587
#   0.02587182]
#  [0.04414815 0.03478007 0.06378234 0.03986366 0.01445947 0.03763339
#   0.02532905]
#  [0.04       0.03390326 0.0646744  0.04253112 0.00747664 0.03708033
#   0.02491875]
#  [0.04325926 0.03857957 0.06794529 0.04890338 0.01371799 0.03670953
#   0.02459567]
#  [0.04918519 0.0382873  0.07091882 0.04697688 0.01562277 0.03619418
#   0.02418537]
#  [0.04696296 0.03580301 0.06630984 0.0429757  0.02375957 0.03545885
#   0.02368137]
#  [0.04325926 0.03361099 0.06125483 0.04179016 0.03413772 0.03489322
#   0.02318707]
#  [0.04192593 0.03229578 0.0608088  0.04164197 0.0380506  0.03408877
#   0.02276061]
#  [0.04177778 0.03200351 0.06199822 0.03956728 0.03314171 0.03346029
#   0.02223723]
#  [0.03955556 0.02849627 0.06125483 0.03778897 0.02528992 0.03266212
#   0.02174292]]

# %%
X_test = []
y_test = []
for i in range(RANGE, data_test_x2.shape[0]):
    X_test.append(data_test_x2[i-RANGE:i])
    y_test.append(data_test_y1[i])

X_test_np = np.array(X_test)
y_test_np = np.array(y_test)
print(X_test_np.shape)
print(y_test_np.shape)
# Out:
# (1178, 51, 7)
# (1178,)

# %%
# Y del dataset de pruebas
pyplot.plot(y_test_np)

# %%
sns.distplot(y_train_np, color='red', label = 'Close - Entrenamiento');
sns.distplot(y_test_np, color='green', label = 'Close - Pruebas');
plt.title('Gráfica de distribucion - Close')
plt.xlabel('Precio')
plt.ylabel('Densidad')
plt.legend()
plt.show()

# %%
# Y de Val y Test comparados
pyplot.plot(y_train_np, color = 'red', label = 'Close - Entrenamiento')
#pyplot.plot(y_test_np)
pyplot.plot(y_test_np, color = 'green', label = 'Close - Pruebas')

plt.title('Close en datos de entrenamiento y pruebas')
plt.xlabel('Tiempo')
plt.ylabel('Precio')
plt.legend()
plt.show()

# %%
x_shape = X_train_np.shape[1]
print(x_shape)
y_shape = X_train_np.shape[2]
print(y_shape)
# Out:
# 51
# 7

# %%
regressior = Sequential()

regressior.add(LSTM(units = RANGE, activation = 'relu', return_sequences = True, input_shape = (x_shape, y_shape)))
#regressior.add(Dropout(0.2))

regressior.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
#regressior.add(Dropout(0.2))

regressior.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
#regressior.add(Dropout(0.2))

regressior.add(LSTM(units = 120, activation = 'relu'))
#regressior.add(Dropout(0.2))

regressior.add(Dense(units = 1))
# Out:
# WARNING:tensorflow:From /Users/marami3/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
def coeff_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
regressior.compile(optimizer='adam', loss = 'mean_squared_error', metrics=['mean_squared_error', 'mean_absolute_error', 'mean_absolute_percentage_error', 'cosine_proximity'])

# %%
regressior.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 51, 51)            12036
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 51, 60)            26880
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 51, 80)            45120
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 120)               96480
# _________________________________________________________________
# dense (Dense)                (None, 1)                 121
# =================================================================
# Total params: 180,637
# Trainable params: 180,637
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Model check pointer para almacenar el modelo cada epoca
checkpointer = ModelCheckpoint(filepath=source_data + '/model-{epoch:02d}.hdf5', verbose=1)

# %%
#history = regressior.fit(X_train_np, y_train_np, epochs=EPOCHS, batch_size=BATCH_SIZE, callbacks=[checkpointer])
#history = regressior.fit(X_train_np, y_train_np, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(X_val_np, y_val_np))
#history = regressior.fit(X_train_np, y_train_np, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(X_val_np, y_val_np), callbacks=[checkpointer], shuffle=True)
#history = regressior.fit(X_train_np, y_train_np, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data=(X_val_np, y_val_np))
history = regressior.fit(X_train_np, y_train_np, epochs=EPOCHS, batch_size=BATCH_SIZE)
# Out:
# WARNING:tensorflow:From /Users/marami3/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 4972 samples
# Epoch 1/100
# 4972/4972 [==============================] - 38s 8ms/sample - loss: 0.9960 - mean_squared_error: 0.9960 - mean_absolute_error: 0.3091 - mean_absolute_percentage_error: 27.1229 - cosine_proximity: 0.9895
# Epoch 2/100
# 4972/4972 [==============================] - 44s 9ms/sample - loss: 1.0251e-04 - mean_squared_error: 1.0251e-04 - mean_absolute_error: 0.0079 - mean_absolute_percentage_error: 0.6910 - cosine_proximity: 1.0000
# Epoch 3/100
# 4972/4972 [==============================] - 38s 8ms/sample - loss: 3.3593e-05 - mean_squared_error: 3.3593e-05 - mean_absolute_error: 0.0046 - mean_absolute_percentage_error: 0.4009 - cosine_proximity: 1.0000
# Epoch 4/100
# 4972/4972 [==============================] - 48s 10ms/sample - loss: 2.6565e-05 - mean_squared_error: 2.6565e-05 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 0.3575 - cosine_proximity: 1.0000
# Epoch 5/100
# 4972/4972 [==============================] - 40s 8ms/sample - loss: 1.7439e-05 - mean_squared_error: 1.7438e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 0.2887 - cosine_proximity: 1.0000
# Epoch 6/100
# 4972/4972 [==============================] - 55s 11ms/sample - loss: 2.4520e-05 - mean_squared_error: 2.4520e-05 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 0.3453 - cosine_proximity: 1.0000
# Epoch 7/100
# 4972/4972 [==============================] - 40s 8ms/sample - loss: 1.7100e-05 - mean_squared_error: 1.7100e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 0.2886 - cosine_proximity: 1.0000
# Epoch 8/100
# 4972/4972 [==============================] - 966s 194ms/sample - loss: 1.8197e-05 - mean_squared_error: 1.8197e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 0.2991 - cosine_proximity: 1.0000
# Epoch 9/100
# 4972/4972 [==============================] - 50s 10ms/sample - loss: 1.3689e-05 - mean_squared_error: 1.3689e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 0.2559 - cosine_proximity: 1.0000
# Epoch 10/100
# 4972/4972 [==============================] - 46s 9ms/sample - loss: 1.8443e-05 - mean_squared_error: 1.8443e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 0.2938 - cosine_proximity: 1.0000
# Epoch 11/100
# 4972/4972 [==============================] - 47s 10ms/sample - loss: 2.2377e-05 - mean_squared_error: 2.2377e-05 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 0.3340 - cosine_proximity: 1.0000
# Epoch 12/100
# 4972/4972 [==============================] - 41s 8ms/sample - loss: 2.7891e-05 - mean_squared_error: 2.7891e-05 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 0.3736 - cosine_proximity: 1.0000
# Epoch 13/100
# 4972/4972 [==============================] - 52s 10ms/sample - loss: 1.3316e-05 - mean_squared_error: 1.3316e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 0.2502 - cosine_proximity: 1.0000
# Epoch 14/100
# 4972/4972 [==============================] - 51s 10ms/sample - loss: 1.3245e-05 - mean_squared_error: 1.3245e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 0.2522 - cosine_proximity: 1.0000
# Epoch 15/100
# 4972/4972 [==============================] - 38s 8ms/sample - loss: 1.6192e-05 - mean_squared_error: 1.6192e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 0.2802 - cosine_proximity: 1.0000
# Epoch 16/100
# 4972/4972 [==============================] - 39s 8ms/sample - loss: 1.9097e-05 - mean_squared_error: 1.9097e-05 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 0.3028 - cosine_proximity: 1.0000
# Epoch 17/100
# 4972/4972 [==============================] - 46s 9ms/sample - loss: 2.7055e-05 - mean_squared_error: 2.7055e-05 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 0.3713 - cosine_proximity: 1.0000
# Epoch 18/100
# 4972/4972 [==============================] - 48s 10ms/sample - loss: 1.5731e-05 - mean_squared_error: 1.5731e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 0.2777 - cosine_proximity: 1.0000
# Epoch 19/100
# 4972/4972 [==============================] - 61s 12ms/sample - loss: 2.2917e-05 - mean_squared_error: 2.2917e-05 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 0.3313 - cosine_proximity: 1.0000
# Epoch 20/100
# 4972/4972 [==============================] - 68s 14ms/sample - loss: 1.5449e-05 - mean_squared_error: 1.5449e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 0.2740 - cosine_proximity: 1.0000
# Epoch 21/100
# 4972/4972 [==============================] - 57s 12ms/sample - loss: 1.4284e-05 - mean_squared_error: 1.4284e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 0.2620 - cosine_proximity: 1.0000
# Epoch 22/100
# 4972/4972 [==============================] - 50s 10ms/sample - loss: 1.6865e-05 - mean_squared_error: 1.6865e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 0.2896 - cosine_proximity: 1.0000
# Epoch 23/100
# 4972/4972 [==============================] - 59s 12ms/sample - loss: 1.7138e-05 - mean_squared_error: 1.7138e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 0.2916 - cosine_proximity: 1.0000
# Epoch 24/100
# 4972/4972 [==============================] - 56s 11ms/sample - loss: 2.0909e-05 - mean_squared_error: 2.0909e-05 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 0.3231 - cosine_proximity: 1.0000
# Epoch 25/100
# 4972/4972 [==============================] - 49s 10ms/sample - loss: 1.8048e-05 - mean_squared_error: 1.8048e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 0.2973 - cosine_proximity: 1.0000
# Epoch 26/100
# 4972/4972 [==============================] - 42s 9ms/sample - loss: 1.5867e-05 - mean_squared_error: 1.5867e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 0.2787 - cosine_proximity: 1.0000
# Epoch 27/100
# 4972/4972 [==============================] - 52s 10ms/sample - loss: 1.2440e-05 - mean_squared_error: 1.2440e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 0.2424 - cosine_proximity: 1.0000
# Epoch 28/100
# 4972/4972 [==============================] - 70s 14ms/sample - loss: 2.9301e-05 - mean_squared_error: 2.9301e-05 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 0.3900 - cosine_proximity: 1.0000
# Epoch 29/100
# 4972/4972 [==============================] - 63s 13ms/sample - loss: 1.3290e-05 - mean_squared_error: 1.3290e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 0.2511 - cosine_proximity: 1.0000
# Epoch 30/100
# 4972/4972 [==============================] - 70s 14ms/sample - loss: 1.6801e-05 - mean_squared_error: 1.6801e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 0.2887 - cosine_proximity: 1.0000
# Epoch 31/100
# 4972/4972 [==============================] - 50s 10ms/sample - loss: 1.9116e-05 - mean_squared_error: 1.9116e-05 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 0.3032 - cosine_proximity: 1.0000
# Epoch 32/100
# 4972/4972 [==============================] - 60s 12ms/sample - loss: 1.4239e-05 - mean_squared_error: 1.4239e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 0.2660 - cosine_proximity: 1.0000
# Epoch 33/100
# 4972/4972 [==============================] - 51s 10ms/sample - loss: 2.0041e-05 - mean_squared_error: 2.0041e-05 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 0.3095 - cosine_proximity: 1.0000
# Epoch 34/100
# 4972/4972 [==============================] - 45s 9ms/sample - loss: 1.8913e-05 - mean_squared_error: 1.8913e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 0.3010 - cosine_proximity: 1.0000
# Epoch 35/100
# 4972/4972 [==============================] - 62s 12ms/sample - loss: 1.1994e-05 - mean_squared_error: 1.1994e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 0.2388 - cosine_proximity: 1.0000
# Epoch 36/100
# 4972/4972 [==============================] - 48s 10ms/sample - loss: 1.8069e-05 - mean_squared_error: 1.8069e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 0.2987 - cosine_proximity: 1.0000
# Epoch 37/100
# 4972/4972 [==============================] - 34s 7ms/sample - loss: 1.6894e-05 - mean_squared_error: 1.6894e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 0.2914 - cosine_proximity: 1.0000
# Epoch 38/100
# 4972/4972 [==============================] - 42s 8ms/sample - loss: 1.6462e-05 - mean_squared_error: 1.6462e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 0.2810 - cosine_proximity: 1.0000
# Epoch 39/100
# 4972/4972 [==============================] - 46s 9ms/sample - loss: 2.0369e-05 - mean_squared_error: 2.0369e-05 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 0.3224 - cosine_proximity: 1.0000
# Epoch 40/100
# 4972/4972 [==============================] - 47s 9ms/sample - loss: 1.5234e-05 - mean_squared_error: 1.5234e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 0.2744 - cosine_proximity: 1.0000
# Epoch 41/100
# 4972/4972 [==============================] - 44s 9ms/sample - loss: 1.3722e-05 - mean_squared_error: 1.3722e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 0.2594 - cosine_proximity: 1.0000
# Epoch 42/100
# 4972/4972 [==============================] - 49s 10ms/sample - loss: 1.3120e-05 - mean_squared_error: 1.3120e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 0.2506 - cosine_proximity: 1.0000
# Epoch 43/100
# 4972/4972 [==============================] - 42s 9ms/sample - loss: 1.3379e-05 - mean_squared_error: 1.3379e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 0.2512 - cosine_proximity: 1.0000
# Epoch 44/100
# 4972/4972 [==============================] - 43s 9ms/sample - loss: 1.6843e-05 - mean_squared_error: 1.6843e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 0.2818 - cosine_proximity: 1.0000
# Epoch 45/100
# 4972/4972 [==============================] - 58s 12ms/sample - loss: 1.5444e-05 - mean_squared_error: 1.5444e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 0.2730 - cosine_proximity: 1.0000
# Epoch 46/100
# 4972/4972 [==============================] - 59s 12ms/sample - loss: 1.6138e-05 - mean_squared_error: 1.6138e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 0.2827 - cosine_proximity: 1.0000
# Epoch 47/100
# 4972/4972 [==============================] - 64s 13ms/sample - loss: 1.6076e-05 - mean_squared_error: 1.6076e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 0.2845 - cosine_proximity: 1.0000
# Epoch 48/100
# 4972/4972 [==============================] - 52s 10ms/sample - loss: 2.0485e-05 - mean_squared_error: 2.0485e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 0.3021 - cosine_proximity: 1.0000
# Epoch 49/100
# 4972/4972 [==============================] - 49s 10ms/sample - loss: 1.1117e-05 - mean_squared_error: 1.1117e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 0.2300 - cosine_proximity: 1.0000
# Epoch 50/100
# 4972/4972 [==============================] - 48s 10ms/sample - loss: 1.3841e-05 - mean_squared_error: 1.3841e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 0.2591 - cosine_proximity: 1.0000
# Epoch 51/100
# 4972/4972 [==============================] - 44s 9ms/sample - loss: 1.0686e-05 - mean_squared_error: 1.0686e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 0.2221 - cosine_proximity: 1.0000
# Epoch 52/100
# 4972/4972 [==============================] - 50s 10ms/sample - loss: 1.8301e-05 - mean_squared_error: 1.8301e-05 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 0.3054 - cosine_proximity: 1.0000
# Epoch 53/100
# 4972/4972 [==============================] - 51s 10ms/sample - loss: 1.6601e-05 - mean_squared_error: 1.6601e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 0.2871 - cosine_proximity: 1.0000
# Epoch 54/100
# 4972/4972 [==============================] - 54s 11ms/sample - loss: 1.1225e-05 - mean_squared_error: 1.1225e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 0.2355 - cosine_proximity: 1.0000
# Epoch 55/100
# 4972/4972 [==============================] - 47s 10ms/sample - loss: 1.6149e-05 - mean_squared_error: 1.6149e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 0.2773 - cosine_proximity: 1.0000
# Epoch 56/100
# 4972/4972 [==============================] - 39s 8ms/sample - loss: 1.2895e-05 - mean_squared_error: 1.2895e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 0.2529 - cosine_proximity: 1.0000
# Epoch 57/100
# 4972/4972 [==============================] - 46s 9ms/sample - loss: 1.6017e-05 - mean_squared_error: 1.6017e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 0.2818 - cosine_proximity: 1.0000
# Epoch 58/100
# 4972/4972 [==============================] - 44s 9ms/sample - loss: 1.4875e-05 - mean_squared_error: 1.4875e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 0.2687 - cosine_proximity: 1.0000
# Epoch 59/100
# 4972/4972 [==============================] - 39s 8ms/sample - loss: 1.4208e-05 - mean_squared_error: 1.4208e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 0.2674 - cosine_proximity: 1.0000
# Epoch 60/100
# 4972/4972 [==============================] - 42s 8ms/sample - loss: 1.7673e-05 - mean_squared_error: 1.7673e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 0.2976 - cosine_proximity: 1.0000
# Epoch 61/100
# 4972/4972 [==============================] - 39s 8ms/sample - loss: 9.9017e-06 - mean_squared_error: 9.9017e-06 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 0.2176 - cosine_proximity: 1.0000
# Epoch 62/100
# 4972/4972 [==============================] - 35s 7ms/sample - loss: 1.1701e-05 - mean_squared_error: 1.1701e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 0.2364 - cosine_proximity: 1.0000
# Epoch 63/100
# 4972/4972 [==============================] - 37s 8ms/sample - loss: 1.3259e-05 - mean_squared_error: 1.3259e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 0.2535 - cosine_proximity: 1.0000
# Epoch 64/100
# 4972/4972 [==============================] - 43s 9ms/sample - loss: 1.2154e-05 - mean_squared_error: 1.2154e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 0.2434 - cosine_proximity: 1.0000
# Epoch 65/100
# 4972/4972 [==============================] - 39s 8ms/sample - loss: 1.0540e-05 - mean_squared_error: 1.0540e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 0.2232 - cosine_proximity: 1.0000
# Epoch 66/100
# 4972/4972 [==============================] - 39s 8ms/sample - loss: 1.5950e-05 - mean_squared_error: 1.5950e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 0.2893 - cosine_proximity: 1.0000
# Epoch 67/100
# 4972/4972 [==============================] - 46s 9ms/sample - loss: 1.2275e-05 - mean_squared_error: 1.2275e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 0.2438 - cosine_proximity: 1.0000
# Epoch 68/100
# 4972/4972 [==============================] - 37s 7ms/sample - loss: 1.0476e-05 - mean_squared_error: 1.0476e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 0.2246 - cosine_proximity: 1.0000
# Epoch 69/100
# 4972/4972 [==============================] - 50s 10ms/sample - loss: 1.3437e-05 - mean_squared_error: 1.3437e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 0.2544 - cosine_proximity: 1.0000
# Epoch 70/100
# 4972/4972 [==============================] - 47s 9ms/sample - loss: 1.1210e-05 - mean_squared_error: 1.1210e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 0.2351 - cosine_proximity: 1.0000
# Epoch 71/100
# 4972/4972 [==============================] - 54s 11ms/sample - loss: 1.7651e-05 - mean_squared_error: 1.7651e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 0.2948 - cosine_proximity: 1.0000
# Epoch 72/100
# 4972/4972 [==============================] - 50s 10ms/sample - loss: 1.2063e-05 - mean_squared_error: 1.2063e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 0.2384 - cosine_proximity: 1.0000
# Epoch 73/100
# 4972/4972 [==============================] - 50s 10ms/sample - loss: 8.4954e-06 - mean_squared_error: 8.4954e-06 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 0.2024 - cosine_proximity: 1.0000
# Epoch 74/100
# 4972/4972 [==============================] - 49s 10ms/sample - loss: 1.2013e-05 - mean_squared_error: 1.2013e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 0.2414 - cosine_proximity: 1.0000
# Epoch 75/100
# 4972/4972 [==============================] - 292s 59ms/sample - loss: 1.3355e-05 - mean_squared_error: 1.3355e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 0.2545 - cosine_proximity: 1.0000
# Epoch 76/100
# 4972/4972 [==============================] - 283s 57ms/sample - loss: 2.0709e-05 - mean_squared_error: 2.0709e-05 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 0.3117 - cosine_proximity: 1.0000
# Epoch 77/100
# 4972/4972 [==============================] - 35s 7ms/sample - loss: 1.0654e-05 - mean_squared_error: 1.0654e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 0.2253 - cosine_proximity: 1.0000
# Epoch 78/100
# 4972/4972 [==============================] - 37s 7ms/sample - loss: 1.5441e-05 - mean_squared_error: 1.5441e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 0.2687 - cosine_proximity: 1.0000
# Epoch 79/100
# 4972/4972 [==============================] - 32s 6ms/sample - loss: 1.1912e-05 - mean_squared_error: 1.1912e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 0.2420 - cosine_proximity: 1.0000
# Epoch 80/100
# 4972/4972 [==============================] - 34s 7ms/sample - loss: 8.1631e-06 - mean_squared_error: 8.1631e-06 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 0.1974 - cosine_proximity: 1.0000
# Epoch 81/100
# 4972/4972 [==============================] - 31s 6ms/sample - loss: 1.2839e-05 - mean_squared_error: 1.2839e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 0.2467 - cosine_proximity: 1.0000
# Epoch 82/100
# 4972/4972 [==============================] - 33s 7ms/sample - loss: 1.0187e-05 - mean_squared_error: 1.0187e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 0.2203 - cosine_proximity: 1.0000
# Epoch 83/100
# 4972/4972 [==============================] - 32s 6ms/sample - loss: 1.5290e-05 - mean_squared_error: 1.5290e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 0.2758 - cosine_proximity: 1.0000
# Epoch 84/100
# 4972/4972 [==============================] - 38s 8ms/sample - loss: 7.0342e-06 - mean_squared_error: 7.0342e-06 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 0.1808 - cosine_proximity: 1.0000
# Epoch 85/100
# 4972/4972 [==============================] - 43s 9ms/sample - loss: 8.0857e-06 - mean_squared_error: 8.0857e-06 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 0.1970 - cosine_proximity: 1.0000
# Epoch 86/100
# 4972/4972 [==============================] - 39s 8ms/sample - loss: 1.4416e-05 - mean_squared_error: 1.4416e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 0.2696 - cosine_proximity: 1.0000
# Epoch 87/100
# 4972/4972 [==============================] - 227s 46ms/sample - loss: 1.1916e-05 - mean_squared_error: 1.1916e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 0.2424 - cosine_proximity: 1.0000
# Epoch 88/100
# 4972/4972 [==============================] - 181s 36ms/sample - loss: 9.2282e-06 - mean_squared_error: 9.2282e-06 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 0.2126 - cosine_proximity: 1.0000
# Epoch 89/100
# 4972/4972 [==============================] - 42s 9ms/sample - loss: 9.5125e-06 - mean_squared_error: 9.5125e-06 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 0.2131 - cosine_proximity: 1.0000 22s - loss: 1.1207e-05 - mean_squared_error: 1.1207e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 0.2314 - cosi - ETA: 17s - loss: 1.1135e-05 - mean_squared_erro
# Epoch 90/100
# 4972/4972 [==============================] - 32s 6ms/sample - loss: 1.1442e-05 - mean_squared_error: 1.1442e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 0.2306 - cosine_proximity: 1.0000s - loss: 8.7498e-06 - mean_squared_error: 8.7498e-06 - mean_absolu
# Epoch 91/100
# 4972/4972 [==============================] - 32s 6ms/sample - loss: 1.0905e-05 - mean_squared_error: 1.0905e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 0.2264 - cosine_proximity: 1.0000
# Epoch 92/100
# 4972/4972 [==============================] - 32s 6ms/sample - loss: 1.1471e-05 - mean_squared_error: 1.1471e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 0.2377 - cosine_proximity: 1.0000
# Epoch 93/100
# 4972/4972 [==============================] - 32s 6ms/sample - loss: 9.1880e-06 - mean_squared_error: 9.1880e-06 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 0.2138 - cosine_proximity: 1.0000
# Epoch 94/100
# 4972/4972 [==============================] - 33s 7ms/sample - loss: 1.0084e-05 - mean_squared_error: 1.0084e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 0.2232 - cosine_proximity: 1.0000
# Epoch 95/100
# 4972/4972 [==============================] - 35s 7ms/sample - loss: 1.1909e-05 - mean_squared_error: 1.1909e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 0.2403 - cosine_proximity: 1.0000
# Epoch 96/100
# 4972/4972 [==============================] - 33s 7ms/sample - loss: 1.2518e-05 - mean_squared_error: 1.2518e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 0.2533 - cosine_proximity: 1.0000
# Epoch 97/100
# 4972/4972 [==============================] - 35s 7ms/sample - loss: 1.3369e-05 - mean_squared_error: 1.3369e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 0.2561 - cosine_proximity: 1.0000
# Epoch 98/100
# 4972/4972 [==============================] - 43s 9ms/sample - loss: 6.3206e-06 - mean_squared_error: 6.3206e-06 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 0.1685 - cosine_proximity: 1.0000
# Epoch 99/100
# 4972/4972 [==============================] - 44s 9ms/sample - loss: 1.2584e-05 - mean_squared_error: 1.2584e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 0.2479 - cosine_proximity: 1.0000
# Epoch 100/100
# 4972/4972 [==============================] - 39s 8ms/sample - loss: 7.8649e-06 - mean_squared_error: 7.8649e-06 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 0.1893 - cosine_proximity: 1.0000

# %%
regressior.save( source_data + "17_feb_final_model.hdf5")

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mean_squared_error', 'mean_absolute_error', 'mean_absolute_percentage_error', 'cosine_proximity'])

# %%
#PLOT MSE MAE
plt.figure(figsize=(5,5))
#plt.plot(history.history['val_loss'][1:], color = 'blue', label = 'Val_Loss')
plt.plot(history.history['mean_squared_error'][1:], color = 'red', label = 'MSE')
#plt.plot(history.history['mean_absolute_error'][1:], color = 'blue', label = 'MAE')
plt.title('Loss Model')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#PLOT MSE MAE
plt.figure(figsize=(5,5))
plt.plot(history.history['mean_absolute_percentage_error'][1:], color = 'green', label = 'MAPE')
plt.title('Loss Model')
plt.xlabel('Epochs')
plt.ylabel('Loss - MSE')
plt.legend()
plt.show()

# %%
#Load Model
#filepath = os.path.join(source_data, r'final_model_100Epochs_3Dic.hdf5')
filepath = os.path.join(source_data, r'17_feb_final_model.hdf5')
print(filepath)
model = tf.keras.models.load_model(filepath)
# Out:
# /Users/marami3/Documents/ITESO/IDI3/proj_deep/17_feb_final_model.hdf5
# WARNING:tensorflow:From /Users/marami3/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/marami3/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/marami3/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
y_test_pred = model.predict(X_test_np)
y_test_pred.shape
# Out:
# (1178, 1)

# %%
y_train_pred = model.predict(X_train_np)
y_train_pred.shape
# Out:
# (4972, 1)

# %%
print(y_test_np.shape)
print(y_test_pred.shape)
# Visualising the results
plt.figure(figsize=(14,5))
plt.plot(y_test_np[:], color = 'green', label = 'Real - Close')
plt.plot(y_test_pred[:], color = 'royalblue', label = 'Predicción - Close')
plt.title('Datos de prueba.')
plt.xlabel('Tiempo')
plt.ylabel('Precio')
plt.legend()
plt.show()
# Out:
# (1178,)
# (1178, 1)

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
print('Test MAE:', mean_absolute_error(y_test_np, y_test_pred))#Mean Absolute Error
print('Test RMSE:',np.sqrt(mean_squared_error(y_test_np, y_test_pred)))#Root Mean Squared Error
print('Test MSE:',mean_squared_error(y_test_np, y_test_pred))#Mean Squared Error
print('Test MAPE:',mean_absolute_percentage_error(y_test_np, y_test_pred))#Mean Absolute Percentaje Error
print('Test R2:',r2_score(y_test_np, y_test_pred))#R2 Score
# Out:
# Test MAE: 0.0013198000996626884
# Test RMSE: 0.0018653026144811893
# Test MSE: 3.479353843590361e-06
# Test MAPE: 0.7647376672188302
# Test R2: 0.9419936667496894

# %%
#shift 
y_test_np2 = np.delete(y_test_np, -1)


print(y_test_np2.shape)
print(y_test_pred[1:].shape)
# Visualising the results
plt.figure(figsize=(14,5))
plt.plot(y_test_np2, color = 'green', label = 'Real - Close')
plt.plot(y_test_pred[1:], color = 'royalblue', label = 'Predicción - Close')
plt.title('Datos de prueba. SHIFT')
plt.xlabel('Tiempo')
plt.ylabel('Precio')
plt.legend()
plt.show()
# Out:
# (1177,)
# (1177, 1)

# %%
#SHIFT
print('SHIFT Test MAE:', mean_absolute_error(y_test_np2, y_test_pred[1:]))#Mean Absolute Error
print('SHIFT Test RMSE:',np.sqrt(mean_squared_error(y_test_np2, y_test_pred[1:])))#Root Mean Squared Error
print('SHIFT Test MSE:',mean_squared_error(y_test_np2, y_test_pred[1:]))#Mean Squared Error
print('SHIFT Test MAPE:',mean_absolute_percentage_error(y_test_np2, y_test_pred[1:]))#Mean Absolute Percentaje Error
print('SHIFT Test R2:',r2_score(y_test_np2, y_test_pred[1:]))#R2 Score
# Out:
# SHIFT Test MAE: 0.0011704323835867204
# SHIFT Test RMSE: 0.0013919199956097597
# SHIFT Test MSE: 1.937441274178273e-06
# SHIFT Test MAPE: 0.769676861581316
# SHIFT Test R2: 0.9676083362353656

# %%
# Visualising the results
plt.figure(figsize=(14,5))
plt.plot(y_train_np, color = 'red', label = 'Real - Close')
plt.plot(y_train_pred, color = 'royalblue', label = 'Predicción - Close')
plt.title('Datos de entrenamiento.')
plt.xlabel('Tiempo')
plt.ylabel('Precio')
plt.legend()
plt.show()

# %%
print('Train MAE:', mean_absolute_error(y_train_np, y_train_pred))#Mean Absolute Error
print('Train RMSE:',np.sqrt(mean_squared_error(y_train_np, y_train_pred)))#Root Mean Squared Error
print('Train MSE:',mean_squared_error(y_train_np, y_train_pred))#Mean Squared Error
#print('Test MAPE:',mean_absolute_percentage_error(y_train_np, y_train_pred))#Mean Absolute Percentaje Error
print('Test R2:',r2_score(y_train_np, y_train_pred))#R2 Score
y_train_np2 = np.delete(y_train_np, -1)
print('Test R2 (-1):',r2_score(y_train_np2, y_train_pred[1:]))#R2 Score
# Out:
# Train MAE: 0.0011967376260765133
# Train RMSE: 0.0015686349005414515
# Train MSE: 2.460615451196689e-06
# Test R2: 0.9883093906318489
# Test R2 (-1): 0.9921273489736175

# %%
# Section to implement the ARIMA model from the library statsmodels.tsa.arima_model
# fit model
#model = ARIMA(series, order=(5,1,0))


train, test = y_train_np, y_test_np
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    #print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# Out:
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/marami3/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Test MSE: 0.000

# %%
# plot
plt.figure(figsize=(14,5))
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()

# %%
print('Train MAE:', mean_absolute_error(test, predictions))#Mean Absolute Error
print('Train RMSE:',np.sqrt(mean_squared_error(test, predictions)))#Root Mean Squared Error
print('Train MSE:',mean_squared_error(test, predictions))#Mean Squared Error
# Out:
# Train MAE: 0.00048750551860369466
# Train RMSE: 0.0007395755362077464
# Train MSE: 5.469719737569757e-07

# %%
from forex_python.converter import CurrencyRates
c = CurrencyRates()
c.get_rates('USD')
# Out:
# {'GBP': 0.7682325796,
#  'HKD': 7.7674203969,
#  'IDR': 13652.496538994,
#  'ILS': 3.4269497,
#  'DKK': 6.8944162437,
#  'INR': 71.3816335948,
#  'CHF': 0.9820950623,
#  'MXN': 18.5734194739,
#  'CZK': 22.882325796,
#  'SGD': 1.3887401938,
#  'THB': 31.1748961698,
#  'HRK': 6.8726349792,
#  'EUR': 0.9229349331,
#  'MYR': 4.144993078,
#  'NOK': 9.2637748039,
#  'CNY': 6.9815413013,
#  'BGN': 1.8050761421,
#  'PHP': 50.564836179,
#  'PLN': 3.9335486848,
#  'ZAR': 14.9603137979,
#  'CAD': 1.3229349331,
#  'ISK': 127.0881402861,
#  'BRL': 4.3137055838,
#  'RON': 4.4086755884,
#  'NZD': 1.5564374712,
#  'TRY': 6.0491001384,
#  'JPY': 109.875403784,
#  'RUB': 63.4567604984,
#  'KRW': 1183.848638671,
#  'USD': 1.0,
#  'AUD': 1.4886017536,
#  'HUF': 308.8509460083,
#  'SEK': 9.7206275958}

# %% [markdown]
# Archivo base, donde se separa X y Y correctamente, Y representa el valor Close de la siguiente hora.
# X tiene los historicos. Se separa 5000 para training y el resto para testing.
